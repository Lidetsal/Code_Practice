# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## All questions in this section pertain to one of the datasets listed above in Exam Materials (training_set_data.csv), with the data_dictionary.txt file providing the metadata needed to understand the contents and formats of the .csv.
#
# Please note that the data is still in its raw, original
# form and may require some cleaning and/or standardization.
# If you wish, you may use MS Excel or Google Sheets to create your data visualization. If you choose
# to use R or Python, please place your response in this document, and include your code as
# part2_code.txt.

# %% [markdown]
# Questions
#
#
# ## Using the data set, create a data visualization that shows the relationship between insurance status, age and income. You may choose to use the age and income variables as provided, or bucket them to create categorical variables. You may create a plot with one or more facets. Please
#
# put the plot as an image into the space below.
# In addition, please write 1 to 2 sentences describing the plot.

# %%
training = pd.read_csv('training_set_data.csv')
pd.set_option('display.max_columns', 500)
training.head()
# Out:
#    person_id  age       citizen_status nativity_status  weekly_hours_worked  \
# 0          1   45        citizen_birth     native_born                   15
# 1          2   47        citizen_birth     native_born                   50
# 2          4   26        citizen_birth     native_born                    0
# 3          5   42  citizen_naturalized    foreign_born                    0
# 4          6   79  citizen_naturalized    foreign_born                    0
#
#    total_income  self_employed_income  wage_income  interest_income  \
# 0         908.0                  62.0        800.0             11.0
# 1      180499.0                  49.0     160007.0          20424.0
# 2        7367.0                  93.0          4.0             20.0
# 3       22970.0                  51.0         46.0            283.0
# 4        7941.0                  23.0         94.0             73.0
#
#    other_income marital_status  school_status     sex     when_last_worked  \
# ...

# %%
# for val in training.total_income.values:
#     if val <= 9623:
#         training.total_income = training.total_income.replace({val:'below_9k'})
#     if val > 9623 and val <= 26073:
#         training.total_income = training.total_income.replace({val:'9.6_to_26k'})
#     if val > 26073 and val <= 53183:
#         training.total_income = training.total_income.replace({val:'26k_to_53k'})
#     if val > 53183:
#          training.total_income = training.total_income.replace({val:'above_53k'})

# %%
training.total_income.value_counts()
# Out:
# 182.0      57
# 206.0      52
# 185.0      50
# 208.0      49
# 188.0      49
#            ..
# 25516.0     1
# 29093.0     1
# 94983.0     1
# 59062.0     1
# 23130.0     1
# Name: total_income, Length: 32729, dtype: int64

# %%
# sns.catplot(x="age", hue="uninsured", kind="bar", data=training)

# plt.show()

# %%
# for val in training.age.values:
#     if val <=33:
#         training.age = training.age.replace({val:'18_to_33'})
#     if val > 33 and val <= 49:
#         training.age = training.age.replace({val:'34_to_44'})
#     if val > 49 and val <= 63:
#         training.age = training.age.replace({val:'50_to_63'})
#     if val > 63:
#          training.age = training.age.replace({val:'above_60'})

# %%
df = training[['age', 'total_income', 'uninsured']]
df.head()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59597 entries, 0 to 59596
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           59597 non-null  int64
#  1   total_income  59597 non-null  float64
#  2   uninsured     59597 non-null  int64
# dtypes: float64(1), int64(2)
# memory usage: 1.4 MB

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(data=training , x= 'age', y= 'total_income',  
                hue='uninsured')

plt.title('Insurance status, Age and Income', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Total Income', fontsize=15)
plt.legend(title='Insurance Status', loc='upper right', fontsize=10 )


plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=training, x='age', y='total_income', hue='uninsured', )

label = ['insured', 'uninsured']

plt.title('Insurance status, Age and Income', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Total Income (USD)', fontsize=15)
plt.yticks(np.arange(0, 150000, step=25000))

plt.legend(title='Insurance Status', loc='upper right', fontsize=10, labels=['Insured', 'Uninsured'])


plt.show()
